# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\suryanarayan\appdata\local\programs\python\python311\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\suryanarayan\appdata\local\programs\python\python311\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\suryanarayan\appdata\local\programs\python\python311\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\suryanarayan\appdata\local\programs\python\python311\lib\site-packages (3.8.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\suryanarayan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\suryanarayan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\suryanarayan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\suryanarayan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\suryanarayan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\suryanarayan\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\suryanarayan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\suryanarayan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\suryanarayan\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\suryanarayan\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
image = cv2.imread('bottles.jpg')
plt.imshow(image)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap="gray")

# %%
blur = cv2.GaussianBlur(gray,(11,11),0)
plt.imshow(blur,cmap="gray")

# %%
canny = cv2.Canny(blur, 30,300,3)
plt.imshow(canny,cmap="gray")

# %%
dilated = cv2.dilate(canny,(1,1),iterations=0)
plt.imshow(dilated,cmap="gray")

# %%
(cnt, hierarchy) = cv2.findContours(dilated.copy(),cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
rgb= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb,cnt,-1,(0,2,0),2)

print("Bottles in the image is :", len(cnt))
plt.imshow(rgb)
# Out:
# Bottles in the image is : 5

# %%
image= cv2.imread('coins.jpg')
plt.imshow(image)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %%
blur = cv2.GaussianBlur(gray,(11,11),0)
plt.imshow(blur, cmap='gray')

# %%
canny = cv2.Canny(blur, 10,320,3)
plt.imshow(canny,cmap="gray")

# %%
dilated = cv2.dilate(canny,(1,1), iterations=0)
plt.imshow(dilated, cmap='gray')

# %%
(cnt, hierarchy) = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb,cnt,-1,(0,2455,0),2)

print('COins in the image :',len(cnt))

plt.imshow(rgb)
# Out:
# COins in the image : 21
